# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)

cap.set(4, 480)

# model
model = YOLO("yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow("Webcam", img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 6.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 8.6ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 5.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.1ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.3ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.6ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.1ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2.1ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.9ms preprocess, 2.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.1ms preprocess, 2.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.5ms preprocess, 1.0ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.8ms preprocess, 6.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.2ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.5ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 8.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.8ms preprocess, 1.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.9ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.4ms preprocess, 2.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.1ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.4ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.4ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 0.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 5.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.7ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.2ms preprocess, 7.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.2ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.0ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.6ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.2ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 2.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.4ms preprocess, 0.3ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.7ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.8ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 0.0ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.5ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.1ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 2.1ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.0ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 0.0ms preprocess, 8.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.2ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 10.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 2.5ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.1ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.0ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.4ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 2.7ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.6ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.2ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.3ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.4ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.2ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 5.3ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.4ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.7ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.6ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 8.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.1ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.2ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.8ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.2ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.1ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.7ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.2ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.8ms preprocess, 10.5ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.3ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.3ms preprocess, 7.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.6ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.3ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 8.3ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 1 chair, 10.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.0ms preprocess, 10.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 1 chair, 12.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 9.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 10.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 11.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 remote, 8.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> remote
# Speed: 2.4ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 remote, 5.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> remote
# Speed: 3.1ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 13.9ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 0.0ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 10.9ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 8.0ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 12.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 9.1ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.1ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 12.6ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 9.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 7.0ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 10.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.48
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 6.8ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.48
# Class name --> laptop
# Speed: 0.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 12.3ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.48
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 11.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 12.3ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 10.1ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 8.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> laptop
# Speed: 0.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 12.1ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 11.7ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 11.2ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Speed: 0.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 10.0ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 10.0ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 7.8ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.48
# Class name --> laptop
# Speed: 0.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 12.4ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> cell phone
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 9.2ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> cell phone
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 9.4ms
# Confidence ---> 0.81
# Class name --> cell phone
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 10.0ms
# Confidence ---> 0.81
# Class name --> cell phone
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.3ms
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 7.4ms
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.9ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 6.6ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
# Speed: 1.9ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 10.6ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 15.1ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 7.2ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
# Speed: 0.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 7.4ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
# Speed: 0.0ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 6.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 2.3ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.1ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.6ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 1.8ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 12.3ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12.8ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.0ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13.4ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13.4ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 0.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6.9ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 2.7ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 8.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 3.2ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 10.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Speed: 2.2ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 10.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 7.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 10.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 8.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 2.2ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 9.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 7.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
# Speed: 3.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
# Speed: 0.0ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 12.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
# Confidence ---> 0.45
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 5.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 1.8ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 10.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 0.0ms preprocess, 10.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 9.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Speed: 0.0ms preprocess, 9.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 9.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> laptop
# Speed: 4.7ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
# Speed: 0.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
# Speed: 3.0ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 12.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 7.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 2.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 8.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 6.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.61
# Class name --> cell phone
# Speed: 2.2ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Speed: 0.0ms preprocess, 10.0ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Speed: 0.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 9.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.58
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> laptop
# Speed: 2.0ms preprocess, 9.2ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 12.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.58
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> laptop
# Speed: 0.0ms preprocess, 12.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 7.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 1.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 0.0ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 6.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.1ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 9.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 9.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 9.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 7.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 2.7ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 7.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 2.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 11.3ms
# ...
# Speed: 2.8ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 2.2ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.8ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 3.6ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.7ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 3.8ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.7ms preprocess, 9.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.4ms preprocess, 7.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.2ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 16.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.4ms preprocess, 5.8ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.6ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.1ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.6ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.3ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.4ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.3ms preprocess, 5.0ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 8.8ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.9ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.1ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.4ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.3ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.5ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.2ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.1ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.4ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.3ms preprocess, 9.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 10.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.3
# Class name --> tie
# Speed: 0.0ms preprocess, 10.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 9.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.3
# Class name --> tie
# Speed: 2.4ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.3ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.6ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.2ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.9ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 6.7ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.9ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.4ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.4ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 11.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.4ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 7.7ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.8ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.9ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.5ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
from ultralytics import YOLO
import cv2
import math

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# Load YOLO model
model = YOLO("yolov8n.pt")

# Object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

while True:
    success, img = cap.read()
    if not success:
        break

    # Get predictions
    results = model(img)

    # Process results
    for r in results:
        for box in r.boxes:
            # Bounding box coordinates
            x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())

            # Draw rectangle
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Confidence
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # Class name
            cls = int(box.cls[0])
            class_name = classNames[cls]
            print("Class name -->", class_name)

            # Display details on image
            org = (x1, y1 - 10)
            text = f'{class_name} {confidence:.2f}'
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 0.5
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, text, org, font, fontScale, color, thickness)

    # Show webcam feed
    cv2.imshow("Webcam", img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.67
# Class name --> person
#
# 0: 480x640 1 person, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 6.9ms
# Speed: 0.1ms preprocess, 6.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 5.9ms
# Speed: 3.6ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 1.4ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 4.6ms
# Speed: 0.0ms preprocess, 4.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 7.2ms
# Speed: 3.3ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.76
# Class name --> person
#
# 0: 480x640 1 person, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.77
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.3ms preprocess, 0.0ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.79
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.77
# Class name --> person
#
# 0: 480x640 1 person, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.81
# Class name --> person
#
# 0: 480x640 1 person, 6.8ms
# Speed: 0.0ms preprocess, 6.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 4.4ms
# Speed: 2.6ms preprocess, 4.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.79
# Class name --> person
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 4.8ms
# Speed: 1.9ms preprocess, 4.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.77
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.79
# Class name --> person
#
# 0: 480x640 1 person, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 0.6ms
# Speed: 0.0ms preprocess, 0.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.79
# Class name --> person
#
# 0: 480x640 1 person, 6.9ms
# Speed: 0.0ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 2.4ms preprocess, 0.0ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.77
# Class name --> person
#
# 0: 480x640 1 person, 5.9ms
# Speed: 0.0ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 5.4ms
# Speed: 0.0ms preprocess, 5.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 1.6ms preprocess, 0.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.79
# Class name --> person
#
# 0: 480x640 1 person, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 4.2ms
# Speed: 2.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 0.0ms
# Speed: 1.8ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 3.5ms
# Speed: 0.0ms preprocess, 3.5ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 3.3ms
# Speed: 1.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 4.0ms
# Speed: 0.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 7.7ms
# Speed: 0.0ms preprocess, 7.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 3.2ms
# Speed: 1.9ms preprocess, 3.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 7.3ms
# Speed: 0.0ms preprocess, 7.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.6ms preprocess, 8.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.9ms
# Speed: 0.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.78
# Class name --> person
#
# 0: 480x640 1 person, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 7.3ms
# Speed: 2.9ms preprocess, 7.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.8
# Class name --> person
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 5.9ms
# Speed: 0.9ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.83
# Class name --> person
#
# 0: 480x640 1 person, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.81
# Class name --> person
#
# 0: 480x640 1 person, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.74
# Class name --> person
#
# 0: 480x640 1 person, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.69
# Class name --> person
#
# 0: 480x640 1 person, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.1ms
# Speed: 0.0ms preprocess, 8.1ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 1 tennis racket, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.33
# Class name --> tennis racket
#
# 0: 480x640 1 person, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 7.7ms
# Speed: 2.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 7.2ms
# Speed: 0.0ms preprocess, 7.2ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 8.9ms
# Speed: 0.0ms preprocess, 8.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.85
# Class name --> person
#
# 0: 480x640 1 person, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.1ms
# Speed: 2.7ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.84
# Class name --> person
#
# 0: 480x640 1 person, 9.1ms
# Speed: 0.3ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 7.9ms
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 8.3ms
# Speed: 0.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.86
# Class name --> person
#
# 0: 480x640 1 person, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 11.1ms
# Speed: 0.4ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 7.7ms
# Speed: 0.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
#
# 0: 480x640 1 person, 10.8ms
# Speed: 0.3ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.87
# Class name --> person
